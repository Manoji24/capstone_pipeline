# %% [markdown]
# # Default notebook
#
# This default notebook is executed using Databricks Workflows as defined in resources/capstone_pipeline.job.yml.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from capstone_pipeline import main

main.get_taxis(spark).show(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from capstone_pipeline import main
#       3 main.get_taxis(spark).show(10)
#
# File c:\Projects\capstone_pipeline\src\capstone_pipeline\main.py:1
# ----> 1 from pyspark.sql import SparkSession, DataFrame
#       4 def get_taxis(spark: SparkSession) -> DataFrame:
#       5     return spark.read.table("samples.nyctaxi.trips")
#
# ModuleNotFoundError: No module named 'pyspark'
