# %% [markdown]
# # Pytest Demo Notebook
#
# ## Summary
# - Purpose: Run the test suite from inside a notebook and demonstrate CI-style test execution in Databricks.
# - Inputs: Project test files under `tests/`
# - Outputs: Pytest run results printed in the notebook; cell fails if tests fail.
# - Audit: N/A (testing only)
#
# ## Usage
# - Run this notebook to execute the repository tests in the cluster environment.

# %%
# %pip install pytest pytest-cov databricks-connect
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Projects\capstone_pipeline_etl\.venv\Scripts\python.exe: No module named pip

# %%
dbutils.library.restartPython()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dbutils.library.restartPython()
#
# File c:\Projects\capstone_pipeline_etl\.venv\Lib\site-packages\databricks\sdk\dbutils.py:264, in RemoteDbUtils.__getattr__(self, util)
#     260 def __getattr__(self, util) -> "_ProxyUtil":
#     261     return _ProxyUtil(
#     262         command_execution=self._commands,
#     263         context_factory=self._running_command_context,
# --> 264         cluster_id=self._cluster_id,
#     265         name=util,
#     266     )
#
# File c:\Projects\capstone_pipeline_etl\.venv\Lib\site-packages\databricks\sdk\dbutils.py:247, in RemoteDbUtils._cluster_id(self)
#     245 if not cluster_id:
#     246     message = "cluster_id is required in the configuration"
# --> 247     raise ValueError(self._config.wrap_debug_info(message))
#     248 return cluster_id
#
# ...

# %%
import pytest
import sys

# Skip writing pyc files on a readonly filesystem.
sys.dont_write_bytecode = True

# Run pytest.
retcode = pytest.main([".", "-v", "-p", "no:cacheprovider"])

# Fail the cell execution if there are any test failures.
assert retcode == 0, "The pytest invocation failed. See the log for details."
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-9.0.2, pluggy-1.6.0 -- c:\Projects\capstone_pipeline_etl\.venv\Scripts\python.exe
# rootdir: c:\Projects\capstone_pipeline_etl
# configfile: pyproject.toml
# plugins: cov-7.0.0, typeguard-4.3.0
# collecting ... collected 9 items
#
# test_main.py::test_add_audit_columns_calls_withcolumn_in_order PASSED    [ 11%]
# test_main.py::test_create_table_bronze_invokes_toTable_and_checkpoint PASSED [ 22%]
# test_main.py::test_audit_log_writes_delta_and_calls_display PASSED       [ 33%]
# test_main.py::test_transform_inticap_applies_initcap PASSED              [ 44%]
# test_main.py::test_transform_clean_digits_removes_non_numeric PASSED     [ 55%]
# test_main.py::test_transform_clean_currency_removes_symbols PASSED       [ 66%]
# test_main.py::test_transform_clean_timestamp_applies_timezone_and_utc PASSED [ 77%]
# ...
