# %%
# %pip install pytest
# Out:
# Collecting pytest
#   Using cached pytest-9.0.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: colorama>=0.4 in c:\projects\.venv\lib\site-packages (from pytest) (0.4.6)
# Collecting iniconfig>=1.0.1 (from pytest)
#   Using cached iniconfig-2.3.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging>=22 in c:\projects\.venv\lib\site-packages (from pytest) (25.0)
# Collecting pluggy<2,>=1.5 (from pytest)
#   Using cached pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygments>=2.7.2 in c:\projects\.venv\lib\site-packages (from pytest) (2.19.2)
# Using cached pytest-9.0.2-py3-none-any.whl (374 kB)
# Using cached pluggy-1.6.0-py3-none-any.whl (20 kB)
# Using cached iniconfig-2.3.0-py3-none-any.whl (7.5 kB)
# Installing collected packages: pluggy, iniconfig, pytest
#
#    ------------- -------------------------- 1/3 [iniconfig]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    ---------------------------------------- 3/3 [pytest]
#
# Successfully installed iniconfig-2.3.0 pluggy-1.6.0 pytest-9.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytest
import sys

# Skip writing pyc files on a readonly filesystem.
sys.dont_write_bytecode = True

# Run pytest.
retcode = pytest.main([".", "-v", "-p", "no:cacheprovider"])

# Fail the cell execution if there are any test failures.
assert retcode == 0, "The pytest invocation failed. See the log for details."
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-9.0.2, pluggy-1.6.0 -- c:\Projects\.venv\Scripts\python.exe
# rootdir: c:\Projects\capstone_pipeline
# configfile: pyproject.toml
# collecting ... collected 1 item
#
# main_test.py::test_main PASSED                                           [100%]
#
# ============================= 1 passed in 21.83s ==============================
