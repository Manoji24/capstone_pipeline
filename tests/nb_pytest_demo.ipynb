# %%
# %pip install pytest
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Projects\capstone_pipeline_etl\.venv\Scripts\python.exe: No module named pip

# %%
import pytest
import sys

# Skip writing pyc files on a readonly filesystem.
sys.dont_write_bytecode = True

# Run pytest.
retcode = pytest.main([".", "-v", "-p", "no:cacheprovider"])

# Fail the cell execution if there are any test failures.
assert retcode == 0, "The pytest invocation failed. See the log for details."
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-9.0.2, pluggy-1.6.0 -- c:\Projects\capstone_pipeline_etl\.venv\Scripts\python.exe
# rootdir: c:\Projects\capstone_pipeline_etl
# configfile: pyproject.toml
# plugins: cov-7.0.0
# collecting ... collected 15 items
#
# main_test.py::test_add_audit_columns_calls_withcolumn_in_order PASSED    [  6%]
# main_test.py::test_create_table_bronze_invokes_toTable_and_checkpoint PASSED [ 13%]
# main_test.py::test_audit_log_writes_delta_and_calls_display PASSED       [ 20%]
# main_test.py::test_transform_inticap_applies_initcap PASSED              [ 26%]
# main_test.py::test_transform_clean_digits_removes_non_numeric PASSED     [ 33%]
# main_test.py::test_transform_clean_currency_removes_symbols PASSED       [ 40%]
# main_test.py::test_transform_clean_timestamp_applies_timezone_and_utc PASSED [ 46%]
# main_test.py::test_fiter_corrupt_records_filters_nulls_and_y PASSED      [ 53%]
# main_test.py::test_transform_hashvalue_creates_sha2_hash PASSED          [ 60%]
# main_test.py::test_transform_inticap_with_real_data PASSED               [ 66%]
# main_test.py::test_transform_clean_digits_with_real_data PASSED          [ 73%]
# main_test.py::test_transform_clean_currency_with_real_data PASSED        [ 80%]
# main_test.py::test_transform_clean_timestamp_with_real_data PASSED       [ 86%]
# main_test.py::test_fiter_corrupt_records_with_real_data PASSED           [ 93%]
# main_test.py::test_transform_hashvalue_with_real_data PASSED             [100%]
#
# ============================= 15 passed in 2.87s ==============================
