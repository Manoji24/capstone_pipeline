# %%
# %pip install pytest
# Out:
# Requirement already satisfied: pytest in c:\users\manoj\appdata\local\programs\python\python311\lib\site-packages (9.0.2)
# Requirement already satisfied: colorama>=0.4 in c:\users\manoj\appdata\roaming\python\python311\site-packages (from pytest) (0.4.6)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\manoj\appdata\local\programs\python\python311\lib\site-packages (from pytest) (2.3.0)
# Requirement already satisfied: packaging>=22 in c:\users\manoj\appdata\local\programs\python\python311\lib\site-packages (from pytest) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\manoj\appdata\local\programs\python\python311\lib\site-packages (from pytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\manoj\appdata\roaming\python\python311\site-packages (from pytest) (2.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytest
import sys

# Skip writing pyc files on a readonly filesystem.
sys.dont_write_bytecode = True

# Run pytest.
retcode = pytest.main([".", "-v", "-p", "no:cacheprovider"])

# Fail the cell execution if there are any test failures.
assert retcode == 0, "The pytest invocation failed. See the log for details."
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\manoj\AppData\Local\Programs\Python\Python311\python.exe
# rootdir: c:\Projects\capstone_pipeline
# configfile: pyproject.toml
# plugins: cov-7.0.0
# collecting ... collected 1 item
#
# main_test.py::test_main FAILED                                           [100%]
#
# ================================== FAILURES ===================================
# __________________________________ test_main __________________________________
#
#     def test_main():
# >       taxis = get_taxis(get_spark())
#                           ^^^^^^^^^^^
#
# main_test.py:20:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ..\src\capstone_pipeline\main.py:15: in get_spark
#     return DatabricksSession.builder.serverless(True).getOrCreate()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\databricks\connect\session.py:376: in getOrCreate
#     return self._create(False)
#            ^^^^^^^^^^^^^^^^^^^
# c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\databricks\connect\session.py:445: in _create
#     return self._from_sdkconfig(
# c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\databricks\connect\cache.py:56: in wrapper
#     cache[cache_id] = func(*args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^
# c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\databricks\connect\session.py:582: in _from_sdkconfig
#     validate_session_serverless(session)
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# session = <pyspark.sql.connect.session.SparkSession object at 0x000001B2E097FC50>
#
#     def validate_session_serverless(session: SparkSession) -> None:
#         logger.debug("Validating serverless configuration.")
#
#         msg = f"Databricks Connect {__dbconnect_version__} is unsupported with serverless. " \
#               "Use with caution! "
# >       dbr_version_string = session.client.server_version().dbr_version
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       AttributeError: 'SparkConnectClient' object has no attribute 'server_version'
#
# c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\databricks\connect\validation.py:104: AttributeError
# =========================== short test summary info ===========================
# FAILED main_test.py::test_main - AttributeError: 'SparkConnectClient' object has no attribute 'server_version'
# ============================== 1 failed in 0.34s ==============================
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 11
#       8 retcode = pytest.main([".", "-v", "-p", "no:cacheprovider"])
#      10 # Fail the cell execution if there are any test failures.
# ---> 11 assert retcode == 0, "The pytest invocation failed. See the log for details."
#
# AssertionError: The pytest invocation failed. See the log for details.
